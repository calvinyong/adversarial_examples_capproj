# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import numpy as np
from keras.models import load_model
from keras.utils import to_categorical

import sys
sys.path.append('../../Final_notebook/')
import proj_utils as utils
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('oid_3class_xception_log.csv')
df.epoch += 1
df.tail()
# Out:
#      epoch       acc      loss   val_acc  val_loss
# 145    146  0.961333  0.099489  0.877333  0.413235
# 146    147  0.954667  0.125690  0.880000  0.409716
# 147    148  0.966667  0.102996  0.877333  0.410856
# 148    149  0.965333  0.105178  0.877333  0.410988
# 149    150  0.964667  0.108126  0.882667  0.407957

# %%
f, ax = plt.subplots(figsize=(13, 6))
ax.set_title('OIDV4 3 Class Xception Acc')
ax = sns.lineplot(data=df[['acc', 'val_acc']], dashes=False)
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
f, ax = plt.subplots(figsize=(13, 6))
ax.set_title('OIDV4 3 Class Xception Loss')
ax = sns.lineplot(data=df[['loss', 'val_loss']], dashes=False)
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
df.iloc[[58, 71, 72, 81, 82, 102]]
# Out:
#      epoch       acc      loss   val_acc  val_loss
# 58      59  0.816667  0.480707  0.828000  0.488142
# 71      72  0.852667  0.366810  0.841333  0.418277
# 72      73  0.848000  0.379415  0.860000  0.390083
# 81      82  0.916000  0.242338  0.873333  0.362091
# 82      83  0.922000  0.199876  0.881333  0.335678
# 102    103  0.945333  0.150096  0.888000  0.400833

# %%
df = pd.read_csv('oid_3class_InceptionV3_log.csv')
df.epoch += 1
df.tail()
# Out:
#      epoch       acc      loss   val_acc  val_loss
# 195    196  0.954667  0.112990  0.876000  0.460693
# 196    197  0.969333  0.086750  0.876000  0.459661
# 197    198  0.961333  0.094075  0.873333  0.460495
# 198    199  0.967333  0.100388  0.873333  0.461470
# 199    200  0.964000  0.101467  0.874667  0.461429

# %%
f, ax = plt.subplots(figsize=(13, 6))
ax.set_title('OIDV4 3 Class InceptionV3 Acc')
ax = sns.lineplot(data=df[['acc', 'val_acc']], dashes=False)
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
f, ax = plt.subplots(figsize=(13, 6))
ax.set_title('OIDV4 3 Class Xception Loss')
ax = sns.lineplot(data=df[['loss', 'val_loss']], dashes=False)
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
df.iloc[[63, 83, 85, 92, 96, 97, 111]]
# Out:
#      epoch       acc      loss   val_acc  val_loss
# 63      64  0.828000  0.438895  0.842667  0.432766
# 83      84  0.904000  0.257025  0.864000  0.338120
# 85      86  0.914667  0.222248  0.868000  0.331659
# 92      93  0.924667  0.198512  0.869333  0.372399
# 96      97  0.932667  0.192821  0.870667  0.359039
# 97      98  0.940667  0.163029  0.873333  0.378165
# 111    112  0.954000  0.137776  0.880000  0.422715

# %%
x_test, y_test = utils.load_oid3class_data()

# %%
i = 748
print(y_test[i])
plt.imshow(x_test[i])
# Out:
# [0. 0. 1.]

# %%
model = load_model('../../Saved_models/good_models/oid_3class/oid_3class_xception_083.h5')

# %%
model.evaluate(x_test, y_test)
# Out:
# 750/750 [==============================] - 11s 15ms/step
# [0.3356774924596151, 0.881333333492279]

# %%
model = load_model('../../Saved_models/good_models/oid_3class/oid_3class_inceptionV3_098.h5')

# %%
model.evaluate(x_test, y_test)
# Out:
# 750/750 [==============================] - 8s 10ms/step
# [0.3781654719511668, 0.8733333328564962]

# %%
model = load_model('../../Saved_models/pretrained_models/oid_3class_InceptionResnet_pretrain.h5')

# %%
model.evaluate(x_test, y_test)
# Out:
# 750/750 [==============================] - 15s 20ms/step
# [0.135683589220047, 0.9866666666666667]
